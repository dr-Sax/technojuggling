# %% [markdown]
# # Juggling Lab
# ---
# ### Sections
# * #### [How To Juggling Lab](#amiga)
# * #### [Not Just for Fun](#reds-dream)
# * #### [Juggling Lab Tumblr Community Analysis](#tumblr_analysis)
#   * ##### [Labor](#labor)
#   * ##### [Technology](#tech)
#   * ##### [Text & Numbers](#text)
#   * ##### [Geometries](#geo)
#   * ##### [Juggle-Ception](#ception)
#   * ##### [Gestures](#gestures)
#   * ##### [Group Dynamics](#groups)
#   * ##### [Pairs](#pairs)
#   * ##### [Sciences](#sciences)
#   * ##### [Legs & Alternative Bodies](#bodies)
#   * ##### [Spinoffs](#spinoffs)
# * #### [Body Esolangs and Humanistic Movement Design](#gregory-barsamian)
# * #### [Siteswaps for Juggling Tables](#dream-machine-volumes)
# ---

# %%
# Imports
from IPython.display import IFrame, display, HTML
import os
import subprocess
from helper_functions import display_images, display_videos, display_videofiles, youtube_player_advanced, display_webvideos, scrape_tumblr_post

# %% [markdown]
# ## How to Juggling Lab

# %%
ref https://www.tumblr.com/lolmatdi1/794441731071508480/you-are-on-this-council-but-we-do-not-grant-you?source=share

Avatar
lolmatdi1
Original Poster
People love my juggling gif

Avatar
fagenthusiast
SERIOUS HOW DO  YOU MAKE THESE THE SOFTWARE IS SO HARD TO UNDERSTAND

lolmatdi1
Original Poster
@fagenthusiast Just mess around with it until you get something funny

fagenthusiast
@lolmatdi1 what interface do you use, the jsm or the html or the simple editor

lolmatdi1
Original Poster
@fagenthusiast I just like type patterns I think might be funny in

...

# %%
There are multiple ways to create animations with Juggling Lab as supported by Jack Boyce.  This includes a Java App where animations
can be detailed either through GUI fields or uploadable JML scripts.  Without the java app, users can still create animations via a web-url based
gif engine which is sharable via link.  All of these methods entail manipulation of the same parameters including siteswap based pattern input, 
prop parameter manipulations, body positioning, hand movements, and more.  A full parameter list can be found here: https://jugglinglab.org/html/sspanel.html

It is not as common that Tumblr user's supply the siteswap or input params used to generate their animations.  These posts often serve as jokes and not
meant to be how to guides for replication.  Often in the comments if someone asks how to, they are met with a joke-based response such as needing to 
mess around and find out.  This may amount to some mixture of guessing and method learning with siteswap sequences and
hardcoding xyz position movements, of balls, bodies, and hands.  Also, the popular feature of ball image props can only be changed within the Juggling Lab
Desktop App and not in the gif server.

More advanced creators have taken to scription to procedurally generate complex algorithmic siteswap patterns as well as mathematically evolving movement
patterns.   Often these more advanced creators will share github pages or images of sample code to indicate how other users can replicate their work.

# %%
path = "https://jugglinglab.org/html/jml.html"
IFrame(path, width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://jugglinglab.org/html/jml.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
# ## Not Just For Fun - Geoff Cox & Alex McLean

# %%
path = "https://api.zotero.org/users/410483/publications/items/GLYUADU2/file/view"
IFrame(path, width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://api.zotero.org/users/410483/publications/items/GLYUADU2/file/view"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
Geoff Cox and Alex McLean's definition of 'jokes as diagrams of innovative action that represent how humans can diverge from social norms.'
will be applied when 

humour as a social practice that reveals wider social
insights

fun often indicates the use of irony or satiric humour by programmers to jolt the
user out of their usual interactions with normative tools and productive work.


Therefore, and further developing
the analogy between repression and the performativity of software, free software
development (where the code is made openly available/shared) might offer 
therapeutic assistance in putting the programmer in touch with his/her, and
indeed culture’s, sublimated desires repressed under proprietary software development

If normative software could be thought of as software without a body,
might desiring-production be explored through free software development with
a body? As Christopher M. Kelty describes it, ‘geeks’ share a social imaginary
about the production of actually existing alternatives, and as such the free
software movement is an example of a ‘recursive public’, capable of creating and
modifying the domain or platform through which they act.19 In other words,
they share a culture through which their repressed desires find release in the
public domain and body politic.

jokes demonstrate innovative techniques and the possibilities for transforming
the linguistic operating system

mainstream programming languages are Turingcomplete. This means it is possible to write a program in any of the languages
that interprets any other computer language. Therefore the rules of any language
can be changed simply by writing an interpreter for another language within
it; and thereby the scope for breaking rules is boundless. Turing-completeness
extends beyond mainstream language into some surprising places. 

For example, obfuscated programs
written in the brainfuck language consist entirely of punctuation, each of the
eight characters ‘><+-.,[]’ representing a single elementary operation. Brainfuck
is Turing-complete, and so can be used to write any program in theory, but in
practice it is extremely difficult to write any program in it at all. Below is The
Game Of Life implemented in brainfuck

The tortuous nature of brainfuck escapes the world of computation to
be wrought on the human body as bodyfuck, a brainfuck interpreter using
computer vision techniques to map from bodily gestures to the brainfuck
instructionset (like a desiring-machine). The brainfuck demo shows how much
physical exertion is required to produce a short sequence of symbols,41 and
the programmer uses his/her body in a more overt manner than previously
required.

Is it that the siteswap language + juggling lab syntax provides the space for virtual gestures to be explored?  Ones that one doesn't feel comfortable 
producing with ones own body?

https://www.instagram.com/reel/DUGgJzfCaDv/
https://youtu.be/B-L-5P8Pa4A?si=l6gTuKe-eyjyEz72
google mediapipe and olympics
# Out:
#   Cell In[4], line 10
#     indeed culture’s, sublimated desires repressed under proprietary software development
#                   ^
# SyntaxError: invalid character '’' (U+2019)

# %% [markdown]
# ---
# <a id='tumblr_analysis'></a>
# ## Juggling Lab Tumblr Community Analysis

# %% [markdown]
# ---
# <a id='labor'></a>
# ### Labor

# %%
url_list = [
    'https://www.tumblr.com/dieuwt/794963402279763969/sorry-guys-i-wanted-to-post-more-but-my-jugglers?source=share',
    'https://www.tumblr.com/smolfoxbab/794803356804710400?source=share',
    'https://www.tumblr.com/lintwizardly/794693447743340544?source=share',
    'https://www.tumblr.com/myryzza/795186787807084544/barcode-generator?source=share',
    'https://www.tumblr.com/hotdogbrained/795293393742872576?source=share',
    'https://www.tumblr.com/ampersand-amplified/794794040532074496?source=share',
    'https://www.tumblr.com/aquaheartgirl/794706231571955712?source=share',
    'https://www.tumblr.com/datcat11/794807869986029568/never-mind-i-figured-it-out-this-is-called-the?source=share'
]

media_url_list = []
caption_list = []

for url in url_list:
    metadata = scrape_tumblr_post(url)
    media_url_list.append(metadata.get('media_url'))
    caption_list.append(f"{metadata.get('description')}")
HTML(display_images(media_url_list, caption_list))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://64.media.tumblr.com/d25a68cca24ea645b9e7dc5fe6029ed3/eaf13cb2f20b42cc-5e/s1280x1920/4ab48bfd1157a14d2547c7b3ed650c68be6fe587.gif" width="300" height="400" style="border: 1px solid #ccc;"></img>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://64.media.tumblr.com/d25a68cca24ea645b9e7dc5fe6029ed3/eaf13cb2f20b42cc-5e/s1280x1920/4ab48bfd1157a14d2547c7b3ed650c68be6fe587.gif">"💬 37  🔁 17746  ❤️ 38520 · sorry guys. I wanted to post more, but my jugglers have unionized."</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
]

media_url_list = []
caption_list = []

for url in url_list:
    metadata = scrape_tumblr_post(url)
    media_url_list.append(metadata.get('media_url'))
    caption_list.append(f"{metadata.get('description')}")
HTML(display_images(media_url_list, caption_list))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://64.media.tumblr.com/0fe73ad894ff7e8e65d3809c26b6b759/ffad637c18b81edb-ff/s400x600/065ed00fa984b69e65fe1cc1c79980c387fa4180.gif" width="300" height="400" style="border: 1px solid #ccc;"></img>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://64.media.tumblr.com/0fe73ad894ff7e8e65d3809c26b6b759/ffad637c18b81edb-ff/s400x600/065ed00fa984b69e65fe1cc1c79980c387fa4180.gif">"💬 13  🔁 3979  ❤️ 12059 · DIE DIE FUCKING DIE · glad i have a roof over my head otherwise that guy ontop wouldve killed me"</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
# ...

# %% [markdown]
# ---
# <a id='sciences'></a>
# ### Sciences

# %%
url_list = [
    'https://www.tumblr.com/dragonboyteeth/794677848761892864/photons-being-generated-in-a-nuclear-reactor?source=share',
    'https://www.tumblr.com/freak-comes-to-shitpost-here/794731568359997440/me-when-my-anti-gravity-balls-wont-stop-flying?source=share',
    'https://www.tumblr.com/skaiawards/795088010810097664/im-afraid-i-cant-do-that-dave?source=share',
    'https://www.tumblr.com/sssaintyboy/794721387151556608/get-back-here-my-robots?source=share',
    'https://www.tumblr.com/itsme-imtherealone/794948687868592128/if-only-i-had-an-element-with-22-electrons-in?source=share',
    'https://www.tumblr.com/skaiawards/795220043540594689/juggle-fission?source=share',
    'https://www.tumblr.com/ampersand-amplified/794693362503630848/particle-accelerator'    
]

media_url_list = []
caption_list = []

for url in url_list:
    metadata = scrape_tumblr_post(url)
    media_url_list.append(metadata.get('media_url'))
    caption_list.append(f"{metadata.get('description')}")
HTML(display_images(media_url_list, caption_list))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://64.media.tumblr.com/c81017d4726871e6f3e65ace71e36fb9/f2552d8e12cbdfe5-20/s400x600/990971d0f42e16f5f738e8d50453cb2b6a31741b.gif" width="300" height="400" style="border: 1px solid #ccc;"></img>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://64.media.tumblr.com/c81017d4726871e6f3e65ace71e36fb9/f2552d8e12cbdfe5-20/s400x600/990971d0f42e16f5f738e8d50453cb2b6a31741b.gif">"💬 0  🔁 252  ❤️ 483 · Photons being generated in a nuclear reactor"</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://64.media.tumblr.com/e273ccd23d618a65f6275d6df1151149/04a07459cae4725a-64/s400x600/09831af7c63880afabddf7fd19068e49bf45227d.gif" width="300" height="400" style="border: 1px solid #ccc;"></img>
# ...

# %% [markdown]
# ---
# <a id='bodies'></a>
# ### Legs & Alternative Bodies

# %%
In the case of the legs, it is the limitation of the Juggling Lab,
whereby it doesnt have legs, just Arms, a face, and body.  People have responded to this
with generating memes where the stick figure body takes on alternate forms.

Noteably, specific to juggling we have the use of an upturned body to create this form
- its really two jugglers, where one body is ontop of the other and hidden, arms are elongated
resembling feet, and keeping the pattern

# %%
url_list = [
   'https://www.tumblr.com/haydengiggles676/796762256448847872?source=share',
    'https://www.tumblr.com/purplewolfluna/795085630744018944?source=share',
    'https://www.tumblr.com/mercurialventures/794625097504882688/multitasking?source=share',
    'https://www.tumblr.com/fireball-me/794622737383636992/the-juggler-has-evolved?source=share',
    'https://www.tumblr.com/sssaintyboy/794719926528196608/the-climbing-centaur?source=share',
    'https://www.tumblr.com/jan-aki/794716019695452160/i-did-a-juggling-lab?source=share',
    'https://www.tumblr.com/fireball-me/794864459558666240?source=share',
    'https://www.tumblr.com/fireball-me/794622737383636992/the-juggler-has-evolved?source=share',
    'https://www.tumblr.com/haydengiggles676/806394059859083264/on-a-walk-def-not-to-the-competition-with?source=share',
    'https://www.tumblr.com/somethingsomethingwizard/794970512663232512/spider-juggler?source=share'
    'https://www.tumblr.com/fireball-me/796527340503072768/can-you-make-a-scary-spider-walking-around-in?source=share',
    'https://www.tumblr.com/caninecannibalism/797175426447441920/tumblr-for-one-full-week-in-september?source=share'
    'https://www.tumblr.com/the-guy-from-juggling-lab/795059501074186240/pattern-11p0000-0011p00-000011p-body-00207?source=share',
]

media_url_list = []
caption_list = []

for url in url_list:
    metadata = scrape_tumblr_post(url)
    media_url_list.append(metadata.get('media_url'))
    caption_list.append(f"{metadata.get('description')}")
HTML(display_images(media_url_list, caption_list))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://64.media.tumblr.com/189b17299d856dce9fc2486b92ebeb74/ddd71e7b0a8f0bed-b0/s400x600/b92b9314eddee6c4a4c2b1d0c0b2da245bd970ff.gif" width="300" height="400" style="border: 1px solid #ccc;"></img>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://64.media.tumblr.com/189b17299d856dce9fc2486b92ebeb74/ddd71e7b0a8f0bed-b0/s400x600/b92b9314eddee6c4a4c2b1d0c0b2da245bd970ff.gif">"💬 9  🔁 1745  ❤️ 5695 · on a walk. gonna be off for a bit yall"</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://64.media.tumblr.com/ce08783e49f8664498bfcfd184ce11f4/81bc1f99e0c4a412-ef/s400x600/c89f9798dec07127e2902a58d66e6f9539fbb6c2.gif" width="300" height="400" style="border: 1px solid #ccc;"></img>
# ...

# %% [markdown]
# ---
# <a id='spinoffs'></a>
# ### Juggling Lab Augmented

# %% [markdown]
# ---
# <a id='jugglekeyboard'></a>
# #### JuggleKeyboard

# %%
#https://www.tumblr.com/foone/794467453373759488/im-prototyping-a-new-keyboard?source=share
#https://www.tumblr.com/foone/794713609284583424/behold-my-latest-keyboard-the?source=share

url_list = [
   'https://va.media.tumblr.com/tumblr_t2luamT5Yx1urkwds_720.mp4',
]
HTML(display_webvideos(url_list))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <video width="300" height="400" controls autoplay loop style="border: 1px solid #ccc;">
#                 <source src="https://va.media.tumblr.com/tumblr_t2luamT5Yx1urkwds_720.mp4" type="video/mp4">
#                 Your browser does not support the video tag.
#             </video>
#             <figcaption style="text-align: center; margin-top: 10px;">
#                 <a href="https://va.media.tumblr.com/tumblr_t2luamT5Yx1urkwds_720.mp4" target="_blank">tumblr t2luamT5Yx1urkwds 720</a>
#             </figcaption>
#         </figure>
#         </div>

# %% [markdown]
# Iparts970

# %%
HTML(display_videos([
    'https://www.youtube.com/watch?v=5obsle1SKoE',
    'https://www.youtube.com/watch?v=D6s3qcfB-Mw',
    
]))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/5obsle1SKoE"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
#                     allowfullscreen
#                     style="border: 1px solid #ccc;">
#             </iframe>
#             <figcaption style="text-align: center; margin-top: 10px;">
#                 <a href="https://www.youtube.com/watch?v=5obsle1SKoE">Watch on YouTube</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/D6s3qcfB-Mw"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
# ...

# %% [markdown]
# https://github.com/Kcits970/osu2jml - converting beatmaps into juggling lab open src code
# https://www.dropbox.com/scl/fi/b1u9b4uriuxmr4klbctg5/BadApple_JML_Frames.zip?rlkey=oaz22wbandpqwoix9s0gmatmp&e=1&dl=0
# Bad apple was also rendered frame by frame:

# %%
Omnikrabundi - Fun with Juggling Lab Series
Dominik Braun

# %%
HTML(display_videos([
    'https://www.youtube.com/watch?v=f1mKUGOGYEk',
    'https://www.youtube.com/watch?v=yyKuTa8Nmzc',
    'https://www.youtube.com/watch?v=CQaVylbJTHk',
    'https://www.youtube.com/watch?v=vAi1aX7O8lY',
]))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/f1mKUGOGYEk"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
#                     allowfullscreen
#                     style="border: 1px solid #ccc;">
#             </iframe>
#             <figcaption style="text-align: center; margin-top: 10px;">
#                 <a href="https://www.youtube.com/watch?v=f1mKUGOGYEk">Watch on YouTube</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/yyKuTa8Nmzc"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
# ...

# %%
url_list = [
   'https://packaged-media.redd.it/pwcuhu3d95a41/pb/m2-res_720p.mp4?m=DASHPlaylist.mpd&var=sgpssan&v=1&e=1772830800&s=81ff458f90b1f46bc1545c941727dcbf2d301623',
    'assets/juggling-lab/omnikrabundi-method.mp4'
]
HTML(display_webvideos(url_list))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <video width="300" height="400" controls autoplay loop style="border: 1px solid #ccc;">
#                 <source src="https://packaged-media.redd.it/pwcuhu3d95a41/pb/m2-res_720p.mp4?m=DASHPlaylist.mpd&var=sgpssan&v=1&e=1772830800&s=81ff458f90b1f46bc1545c941727dcbf2d301623" type="video/mp4">
#                 Your browser does not support the video tag.
#             </video>
#             <figcaption style="text-align: center; margin-top: 10px;">
#                 <a href="https://packaged-media.redd.it/pwcuhu3d95a41/pb/m2-res_720p.mp4?m=DASHPlaylist.mpd&var=sgpssan&v=1&e=1772830800&s=81ff458f90b1f46bc1545c941727dcbf2d301623" target="_blank">m2-res 720p?m=DASHPlaylist.mpd&var=sgpssan&v=1&e=1772830800&s=81ff458f90b1f46bc1545c941727dcbf2d301623</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
# ...

# %%
HTML(display_images(['assets/juggling-lab/omnikrabundi-motivation.png'],['motivation']))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <img src="assets/juggling-lab/omnikrabundi-motivation.png" width="300" height="400" style="border: 1px solid #ccc;"></img>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="assets/juggling-lab/omnikrabundi-motivation.png">"motivation"</a>
#             </figcaption>
#         </figure>
#         </div>

# %%
foone

https://www.tumblr.com/foone/796181591651188736/its-time-for-doom-juggling-ever-since-the-never?source=share
https://www.tumblr.com/foone/795635409902321664?source=share
https://www.tumblr.com/foone/794713609284583424/behold-my-latest-keyboard-the?source=share

# %%
recreating juggling lab in other places

https://www.tumblr.com/anosci/798161896090058752?source=share
https://www.tumblr.com/anosci/794624110367064064?source=share
https://tixl.app/

desmos juggler
https://www.desmos.com/calculator/ksruhsksm1

calculator
https://www.tumblr.com/herothat/795413355101880320/i-dont-think-this-is-quite-right?source=share

# %%
url_list = [
    'https://www.youtube.com/watch?app=desktop&v=5obsle1SKoE',
    'https://www.tumblr.com/foone/795635409902321664/i-saw-that-someone-had-done-bad?source=share'
    
    
]


bad apple:


ejc (at end)


rick roll turing complete:
https://www.tumblr.com/foone/795635409902321664/i-saw-that-someone-had-done-bad?source=share

# %% [markdown]
# ### Example of a Python Script used to generate siteswap

# %%
effortful construction:

consider how the pair based juggling structure can determine 
can also relate to commentary on technology, science, physics etc
    
https://www.tumblr.com/durdledeese/794975655475478528/heres-the-life-ive-always-longed-for-reference?source=share

https://www.tumblr.com/foobagorch/798331176825831424/behind-the-scenes-this-took-me-three-hours-and-a?source=share

# %%
def num_to_height(n):
    if n < 10:
        return str(n)
    elif n <= 35:  # a=10 ... z=35
        return chr(ord('a') + (n - 10))
    else:
        raise ValueError(f"Height {n} exceeds JugglingLab max (z=35)")

def try2(starting=14, ending=3, delay_1=20, delay_2=2):
    def switch(a, b):
        if b == ending:
            return ''
        type_a  = num_to_height(a)
        type_a2 = num_to_height(a + 1)
        type_b  = num_to_height(b)
        type_b2 = num_to_height(b - 1)
        return (
            f'(<{type_a}|{type_b}>^{delay_1})'
            f'<{type_b}p/{type_a}|{type_a}p/{type_a2}p>'
            f'{switch(a + 1, b - 1)}'
            f'(<{type_a2}|{type_b2}>^{delay_2})'
            f'<{type_b2}p/{type_b}p|{type_b}{type_a}p>'
        )

    type_a  = num_to_height(starting)
    a_plus  = num_to_height(starting + 1)
    a_minus = num_to_height(starting - 1)

    output = (
        f'(<{type_a}|{type_a}>^{delay_1})'
        f'<{type_a}{type_a}|{type_a}{a_plus}p>'
        f'{switch(starting + 1, starting - 1)}'
        f'(<{a_plus}|{a_minus}>^{delay_2})'
        f'<{a_minus}p/{type_a}|{type_a}{type_a}>'
    )
    print(output)

try2(starting=3, ending=1, delay_1= 0, delay_2= 0)
# Out:
# (<3|3>^0)<33|34p>(<4|2>^0)<2p/4|4p/5p>(<5|1>^0)<1p/2p|24p>(<4|2>^0)<2p/3|33>

# %%
https://www.tumblr.com/fireball-me/794791196122824705/think-juggling-is-innocent-wrong-satanism?source=share
https://www.tumblr.com/nonexistent-triangle/794663628919963648/basic-juggling-techniques-for-beginners-the?source=share
https://www.tumblr.com/that-one-burnable-rock/795266861926400001/no-stop-shuffling-the-lifecycle-of-a-frog?source=share
https://www.tumblr.com/ampersand-amplified/795065542942883841/casting-my-evil-spell?source=share
https://www.tumblr.com/ilovejugglinglabs/794897093569527808/the-wizards-begin-learning-simple-levitation?source=share
https://www.tumblr.com/spamton2thesequel/794597732835835905/spiders-spiders-so-many-spiders-oh-hi-yoki-d?source=share
https://www.tumblr.com/vague-velleity/794642255288958976/i-call-this-one-the-spiderweb?source=share
https://www.tumblr.com/draculaugust/794680491335892992/tricky-dicks-dick-tricks?source=share
https://www.tumblr.com/tabbysas/794769606697959424/organization-xiii?source=share
https://www.youtube.com/watch?v=a1XKRxWz8jE spider man ps4 robot scene

# %% [markdown]
# #### Spider man video game teleoperational juggler

# %%
HTML(youtube_player_advanced('a1XKRxWz8jE', 514, 613))
# Out:
#     <div id="player_a1XKRxWz8jE_514_613"></div>
#     <script src="https://www.youtube.com/iframe_api"></script>
#     <script>
#         var player_a1XKRxWz8jE;
#         var done_a1XKRxWz8jE = false;
#
#         function onYouTubeIframeAPIReady() {
#             player_a1XKRxWz8jE = new YT.Player('player_a1XKRxWz8jE_514_613', {
#                 height: '360',
#                 width: '640',
#                 videoId: 'a1XKRxWz8jE',
#                 playerVars: {
#                     'start': 514,
#                     'end': 613,
#                     'autoplay': 1,
#                     'controls': 1
#                 },
#                 events: {
#                     'onReady': onPlayerReady_a1XKRxWz8jE,
#                     'onStateChange': onPlayerStateChange_a1XKRxWz8jE
#                 }
#             });
#         }
#
#         function onPlayerReady_a1XKRxWz8jE(event) {
#             event.target.playVideo();
#         }
#
# ...

# %% [markdown]
# ## How Robotics research informs humanistic movement design

# %%
path = "assets/choreo/live-notation-for-patterns-of-movement-McLean-Sicchio-2024.pdf"

from IPython.display import IFrame

IFrame(path, width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="assets/choreo/live-notation-for-patterns-of-movement-McLean-Sicchio-2024.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
We could stop here in framing our piece at the notational level of the live coding environment.
To do so would be to focus on the notation of movement, rather than the movement itself and its
influence on the human dancers and choreographers. Indeed, this is how we initially approached
control of our robots, looking for ways to pinpoint a position in space using the notation,
instructing each robot to move to that position, through a technique called inverse kinematics.
This extreme level of control is made possible with robots, in that what you write on the computer is what you get.
On closer examination though, such an approach to notation as a technology of control12 is a losing battle. Firstly, in our case, it is not possible for the end point of a robot (i.e., the end of its “nose”)
to move to any given point in space; each robot only has three motors, configured as a mechanical
waist (bottom motor), back (middle motor), and head (top motor), respectively. Because the base of
each robot is fixed to a table, it can only contort to certain positions. Even if the robot was free to
reach any point that we might want it to, we would still have to carefully consider its physical characteristics. It takes time to move; so to reach a particular point at a particular time, you have to start
early. If you move too fast, the robot will overshoot, and resonate back and forward until it settles 

instead worked with the robotic quirks as creative material, exploring issues of vibration
and timing as resonances and rhythms that are intrinsic to the robot, offering up material affordances that we chose to embrace
rather than work against.

Thus, in order to work with any robot, we first need to understand its physical constraints, using these as creative
material to work with. Indeed, this is true also when working with humans. For example, percussionist Jaki Liebezeit,
the founder of the experimental band Can, developed an approach to drumming with a notation based on the binary
dot-dash familiar to morse code (Podmore 2020). The constraints of this system were based on
the observation that in order to perform a louder “accented” strike of the drum, the hand needs to move the drumstick further, 
up and then down, which takes additional time. Liebezeit’s system therefore worked on the interplay between left and right hands,
where due to the laws of physics, an accent with one hand requires time provided by a preceding double movement with the other hand. 
From these simple rules, complex rhythms and paradiddles are generated. Accordingly, rather than seeing the physical constraints of a human or robotic
agent as getting in the way of an ideal notated piece, we take physical constraints as a starting point, therefore providing 
a rich creative space in which to work. So what did our robots do? How did they dance?

As mentioned earlier, we each have one robot, sitting on our respective desks in Richmond and
Sheffield, made from off-the-shelf servo motors. These motors not only allow external control
over where they travel, how fast, and with how much power, but also allow the computer to sense
its current position, and the pressure applied to it. These physical properties present a number of
constraints. For example, it isn’t possible to increase the speed of the robots without increasing the
noise that it makes. The robot also isn’t able to move around or across the surface to which it is
mounted. More subtly, care should also be taken to avoid overusing certain movements that wear
out the components by overheating them or overstressing interconnecting wires.

Such physical properties offer us a number of choices in deciding how we interact with the
robot, for example:
1. If the robot is already moving to a position when you tell it to move to a new one, should it
complete its current move, or immediately adjust its course?
2. Should the robot simply move as quickly as possible to the new position, or should its speed
follow a particular curve of acceleration and deceleration as it reaches its goal?
3. Should a movement be expressed in terms of the average speed of movement, or in terms of the
time the movement should take?
4. Relatedly, should a movement be timed in terms of when the robot arrives at its target position,
or in terms of when the movement begins?
5. How about relative movements, like “switch sides,” or “move halfway to the ground”—should
these movements be relative to the current target position of the moving robot, or to the current
position?

To a large extent, all of these constraints and choices apply just as well to humans as to robots,
with the exception that human muscles tend to move more quietly than servo motors—but human
movements have their noises too, such as gasps, squeaks, and clicks. The primary difference then is
that with robot performers, answers to such questions tend towards control, and with human ones,
the answers tend towards respecting human agency. In considering them together, we are therefore
able to make these choices explicit and open to interrogation.

# %%
In developing motion-centered choregrapy notation for multi-servomotor robots, McLean and Sicchio avoid a top down control
of movement by working with the quirks and physical limitations of motors as a creative material.  Patterns are chosen which 
"avoid overusing certain movements that wear out the components by overheating them or overstressing interconnecting wires."  In this way,
they respect the robot performer by designing a notational system and subsequent movement algorithms which are sustainable and natural to the 
robot's physical structure and hardware capabilities.  Further, they write that "all of these constraints and choices apply just as well to humans as to robots,
with the exception that human muscles tend to move more quietly than servo motors—but human movements have their noises too, such as gasps, squeaks, and clicks"

McLean and Sicchio's approach can be applied when thinking about the relationship between Juggling Animators and human participants.  Juggling Siteswap
animators initially served to conceive of new juggling patterns which could be practiced and learned by humans.  However, unlike McLean and Sicchio's
servo-motor robots, the choregraphing of a virtual juggler through Juggling Lab notational isn't bound to physical limitations and often leads to
non-humanistic movements in the Tumblr community.

But for this project, we can think of the Juggling Table as a unique setting for which to choreograph patterns humanly achievable within in 
geometry and physical forces of the apparatus.  With this in mind, configuration and siteswap commands can allow us to generate human oriented
patterns which bear in mind the possibility for performance.

# %%
# Display extracted PDF
IFrame("assets/choreo/live-coding-choreography-real-time-programming-with-terpsicode-sicchio-2023.pdf", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="assets/choreo/live-coding-choreography-real-time-programming-with-terpsicode-sicchio-2023.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
Terpsicode is an esoteric programming language or esolang. Many esolangs have a
dual purpose of being read by the computer but also holding meaning elsewhere,
known as multiple coding 
Multiple coding allows for code to become a choreographic score for a human while being a programming
language that compiles.

dance terminology + visual performance scores


Esoteric programming languages (esolangs) are often created for a reason other than a
practical application and test the boundaries of programming language design. Esolangs
may be aesthetic, a joke or parody, obfuscatory, or as minimalist as possible. Some of the
most well known esolangs are Brainfuck, Piet, Chef, and Befunge but there are many
others all with their own niche way of operating. Some programming languages specifically made for live coding may be considered esolangs, such as Orca

Esolangs may have a duplicate interpretation, being read by the computer as code but
also being read by a human in another context, such as poetry, recipes or a dance. This is
known as multiple coding or multicoding

# %%
# Brainfuck / BodyFuck
IFrame("https://switch.sjsu.edu/wp/v28/2013/10/28/body-and-imagination-the-work-of-nik-hanselmann/", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://switch.sjsu.edu/wp/v28/2013/10/28/body-and-imagination-the-work-of-nik-hanselmann/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ---
# ## Human Conscious Siteswaps for Juggling Tables

# %%
# 'https://jugglinglab.org/anim?pattern=(8,2x)(4,2x)*;body=.(0,0,0,30).;colors=mixed;propdiam=20'
media_url_list = [
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fd8a35b081bbae30f143c5f64.gif?generation=1772468882491958&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2F78fe2a9074735c0fd0eba917.gif?generation=1772729070981097&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fe5f5e856318af618625601bc.gif?generation=1772729185871075&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2F603d2096c62d5fe02d381f0c.gif?generation=1772729321265270&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fb98617217272d14206c913be.gif?generation=1772729483640384&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2F064c4d919673d786e62894ec.gif?generation=1772729633260641&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fb3b9df578e2f358119a87cad.gif?generation=1772729750664240&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fb897992a317fc15c6dcd7e31.gif?generation=1772730062265765&alt=media',
    'https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2F742366540cf46fac1a2668de.gif?generation=1772730249548994&alt=media'  
]

siteswap = [
    '6B42',
    '(8,2x)(4,2x)*',
    '633',
    '(6x,2x)(2x,2x)',
    '7531',
    '7131',
    'b15151',
    '7441',
    '(4x, 4x)'
]

HTML(display_images(media_url_list, siteswap))
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fd8a35b081bbae30f143c5f64.gif?generation=1772468882491958&alt=media" width="300" height="400" style="border: 1px solid #ccc;"></img>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2Fd8a35b081bbae30f143c5f64.gif?generation=1772468882491958&alt=media">"6B42"</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <img src="https://storage.googleapis.com/download/storage/v1/b/jugglinglab/o/gif%2F78fe2a9074735c0fd0eba917.gif?generation=1772729070981097&alt=media" width="300" height="400" style="border: 1px solid #ccc;"></img>
# ...

# %%
In this case, Juggling Lab is a cultural event users through the tumblr community could take part in watching and then in creation
of memes through Jack Boyce's juggling siteswap generator program.  With regard to the program, it was created by college students at Caltech, noteably
Jack Boyce and Allen Nutson during the the 

okay so practice on the table by using patterns created by juggling lab as "trainers".  

would have to figure way to project the .gif animations into techno juggling as well.
then find a way to trace the artifacts using the Allen Knutson's time pens tool.
playing with the siteswap generator allows me to practice realistic forms for my table
- that would be in reference to creating realistic human movements
 --- hinting at sichio and McLean's reference to humanistic form in robot dance design

But then you have to think about the language of siteswap.  how to perform with it
- because you need to use that language of siteswap to figure out recreate the movement
but deeper down siteswap is its own mathematical frame
-but yeah anyway

So basically you have to write about a few things:

# %%
So in thinking about the virtual reference space, consider that media may be choreographed in relation to time through  the z-axis
play with different distances
- imagine a situation where if you lookin in one direction, you can see the juggling lab siteswap animator, and in the other you can see your own hands
- you still have the live code editor above both so of course you may 
- you build a virtual space where you can rotate and view.  but consider with a down ward gaze
- because the decision to build is based on how we would chose to iteratively develop it

with the next iteration as a tv as the surface with polarizing lens on the camera to block out tv graphics

So in that case your gaze is downwards, so you look into the plane of the ground at the floor with slight angle

As a consequence of the Juggling Lab project when captured in the moment of current times, we can see that there is a transformation
of 

In this case juggling lab is a way to consider programming of bodily movement,
the imaginic tendencies of juggling lab creators lends itself towards a reproduction of the body
this is unlike the tendency in computer graphics at the time you over time you see the decay
of Adam Powers.  The first depiction of a Juggler"s Hand, we can say this because Ed Catmull's
company Pixar eventually with the second animation of Red's Dream, we can see that that
image of adam powers is accompanied by an even higher realism graphic of a unicycle.

But then with the consumer electronics period and production of Animations by platform users
of the Amiga commadore, you have a creation of a juggler which is used to sell more Amigas.
This Juggler though is far more geometrized and this trend continues in the early 80s, but as
as is possible today in the form of Juggling Lab.

With Juggling Lab, the algorithmically controlled body and objects can be controlled in a way
to produces jokes.  In these Jokes we can witness categories of an internet users imagination
with respect to a juggling meme producer

Does Jugglign Lab count as global tv?  No way to know which users are from america vs other
countries..

So with this regard it is the recognition that many subcategories descriptive of the content
witnessed on Juggling Lab.  These subcategories span augmented bodies from the original form
- this morphing of the body doesnt happen alone without also the inclusion of image objects
as balls.

spider as the juggling tutor - or any thing as the tutor- decorate the animator essentially,
its pretty open..

# %%
IFrame("https://econtact.ca/21_1/sicchio_terpsicode.html", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://econtact.ca/21_1/sicchio_terpsicode.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# #### Further iterations

# %%
html = '<iframe src="https://player.vimeo.com/video/1171602382" width="640" height="360" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen></iframe>'
HTML(html)
# Out:
# C:\Users\nicor\OneDrive\Documents\Code\technojuggling\.venv\lib\site-packages\IPython\core\display.py:475: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="https://player.vimeo.com/video/1171602382" width="640" height="360" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen></iframe>

# %%
html = '<iframe width="320" height="576" src="https://www.youtube.com/embed/sqHBrC4mF7g" title="Technojuggling w/ projected graphics on the table.  4 ball box" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'
HTML(html)
# Out:
# <iframe width="320" height="576" src="https://www.youtube.com/embed/sqHBrC4mF7g" title="Technojuggling w/ projected graphics on the table.  4 ball box" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
html = '<iframe width="320" height="576" src="https://www.youtube.com/embed/ocGfyrQwYwI" title="Polarization effect to supress tv display" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'
HTML(html)
# Out:
# <iframe width="320" height="576" src="https://www.youtube.com/embed/ocGfyrQwYwI" title="Polarization effect to supress tv display" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %%
It explores the idea of utilizing still images of dancers as a way of forming discrete units for creating patterns over time. 
These patterns in turn become composed through algorithmic processes. 

Juggling lab as agnostic to any sort of physical or mechanical rules for movement.  It's rules are coded in a purely 
activ

https://vimeo.com/947137874 -- here teleoperation 
- how do we create image onto robots.
- if we do a complete one to one relation - vtubing, we are then just encoding our own bodies as digital animation
- we can see this outlined in mitama's juggling vr
- when working with juggling lab as a code, we are inclined

when thinking about the ps4 juggling robot, we can consider it to be a teleoperation relationship through the mind.

That is what we are we can move the bodies just through thought alone.  but in any case there must be some layer of communication occuring.
- in dr octo's case, it is the brain computer interface which allows him to control the throws and catches of juggling balls with his mind alone.
- this is very much unlike the gestural relation happening in sicchio's case, and also different in the case juggling lab on how they create motion.
now some of sicchio's experiments with live coding terpsicode show reveal how the choreograph, allows for the performer to drift or create agency.

This counters the relation of 
With the output of live-coded choreography being not only a computer-generated performance, but also a human-computer collaboration, 
dancers can move beyond the role of “serving” the machines and can thereby gain agency and the capacity to act in an environment in a personal, 
creative manner. This capacity is the decision-making process that informs the dancers as they execute movements; the environment is the 
resulting choreography, or dance work
https://vimeo.com/1134697111 Analivia Cordeiro

“the dancer is free to describe the trajectory connecting the positions”

so in the case of siteswap, does this language not impose rules on creation of motion, yet it is not one to one so when generate gestural bodies,
there is a level of thought involved in / unconscious manuevering to create an image.  Or very purposeful what could be worrysome but also positive is 
use of juggling lab - a tool that originated out of juggler's playing with siteswap mathematics to create a tool for furthering real juggling

- so in this case we see a fascination in that people (those who may or may not juggle, but enjoy playing around with the juggling simulator) - they 
followed a particular course of creating jokes or modes of deviating from social norms in some way.  But the public certainly, created scenes, those from
social circles, group dynamics pair relations.
