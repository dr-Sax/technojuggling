# %%
# Imports
from IPython.display import IFrame, display, HTML
import os
import subprocess
from helper_functions import display_images, display_videos, display_videofiles, youtube_player_advanced, display_webvideos

# %%
img_url= 'https://www.dev.juggle.org/history/archives/jugmags/images/34-5/34-5,p14-5.jpg'
src_url = 'https://www.dev.juggle.org/history/archives/jugmags/34-5/34-5,p14.htm'
width = 500
height = 150

html = f"""
    <figure style="text-align: center; margin: 0;">
        <img src="{img_url}" width="{width}" height="{height}" style="border: 1px solid #ccc;"></img>
        <figcaption style="text-align: center; margin-top: 1px;">
            <a href="{src_url}">December 1982</a>
        </figcaption>
    </figure>
    """
from IPython.display import HTML
HTML(html)
# Out:
#     <figure style="text-align: center; margin: 0;">
#         <img src="https://www.dev.juggle.org/history/archives/jugmags/images/34-5/34-5,p14-5.jpg" width="500" height="150" style="border: 1px solid #ccc;"></img>
#         <figcaption style="text-align: center; margin-top: 1px;">
#             <a href="https://www.dev.juggle.org/history/archives/jugmags/34-5/34-5,p14.htm">December 1982</a>
#         </figcaption>
#     </figure>

# %% [markdown]
# ### Claude Shannon

# %%
img_url= 'https://www.google.com/logos/doodles/2016/claude-shannons-100th-birthday-5731852344098816.2-hp2x.gif'
src_url = 'https://doodles.google/doodle/claude-shannons-100th-birthday/'
width = 500
height = 150

html = f"""
    <figure style="text-align: center; margin: 0;">
        <img src="{img_url}" width="{width}" height="{height}" style="border: 1px solid #ccc;"></img>
        <figcaption style="text-align: center; margin-top: 1px;">
            <a href="{src_url}">April 30, 2016</a>
        </figcaption>
    </figure>
    """
from IPython.display import HTML
HTML(html)
# Out:
#     <figure style="text-align: center; margin: 0;">
#         <img src="https://www.google.com/logos/doodles/2016/claude-shannons-100th-birthday-5731852344098816.2-hp2x.gif" width="500" height="150" style="border: 1px solid #ccc;"></img>
#         <figcaption style="text-align: center; margin-top: 1px;">
#             <a href="https://doodles.google/doodle/claude-shannons-100th-birthday/">April 30, 2016</a>
#         </figcaption>
#     </figure>

# %%
HTML(youtube_player_advanced('tXU3EPg2cgA', 10, 107))
# Out:
#     <div id="player_tXU3EPg2cgA_10_107"></div>
#     <script src="https://www.youtube.com/iframe_api"></script>
#     <script>
#         var player_tXU3EPg2cgA;
#         var done_tXU3EPg2cgA = false;
#
#         function onYouTubeIframeAPIReady() {
#             player_tXU3EPg2cgA = new YT.Player('player_tXU3EPg2cgA_10_107', {
#                 height: '360',
#                 width: '640',
#                 videoId: 'tXU3EPg2cgA',
#                 playerVars: {
#                     'start': 10,
#                     'end': 107,
#                     'autoplay': 1,
#                     'controls': 1
#                 },
#                 events: {
#                     'onReady': onPlayerReady_tXU3EPg2cgA,
#                     'onStateChange': onPlayerStateChange_tXU3EPg2cgA
#                 }
#             });
#         }
#
#         function onPlayerReady_tXU3EPg2cgA(event) {
#             event.target.playVideo();
#         }
#
# ...

# %% [markdown]
# ## Juggling Apparatuses, Automatons, and Robots

# %%
HTML(youtube_player_advanced('JVtdjKgB75U', 0, 360))
# Out:
#     <div id="player_JVtdjKgB75U_0_360"></div>
#     <script src="https://www.youtube.com/iframe_api"></script>
#     <script>
#         var player_JVtdjKgB75U;
#         var done_JVtdjKgB75U = false;
#
#         function onYouTubeIframeAPIReady() {
#             player_JVtdjKgB75U = new YT.Player('player_JVtdjKgB75U_0_360', {
#                 height: '360',
#                 width: '640',
#                 videoId: 'JVtdjKgB75U',
#                 playerVars: {
#                     'start': 0,
#                     'end': 360,
#                     'autoplay': 1,
#                     'controls': 1
#                 },
#                 events: {
#                     'onReady': onPlayerReady_JVtdjKgB75U,
#                     'onStateChange': onPlayerStateChange_JVtdjKgB75U
#                 }
#             });
#         }
#
#         function onPlayerReady_JVtdjKgB75U(event) {
#             event.target.playVideo();
#         }
#
# ...

# %% [markdown]
# ---
# ### Stephen Meschke

# %%
youtube_urls = [
    'https://www.youtube.com/watch?v=uyq7RJbFZEI', # meschke
    'https://www.youtube.com/watch?v=12DdROaie58',
    'https://www.youtube.com/watch?v=d4yE6yL5cCc',
    'https://www.youtube.com/watch?v=uyq7RJbFZEI',    
]
html = display_videos(youtube_urls)
HTML(html)
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/uyq7RJbFZEI"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
#                     allowfullscreen
#                     style="border: 1px solid #ccc;">
#             </iframe>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://www.youtube.com/watch?v=uyq7RJbFZEI">Watch on YouTube</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/12DdROaie58"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
# ...

# %%
videos = [
        'https://www.youtube.com/watch?v=kSJqxs2Jh-I',
        'https://www.youtube.com/watch?v=M4f4xVJPrs4',
        'https://www.youtube.com/watch?v=qnJEeB7GykU',
        'https://www.youtube.com/watch?v=33dSDsLLGCY',
        'https://www.youtube.com/watch?v=ebPt195JIIk', # juggling machine
        'https://www.youtube.com/watch?v=-9zD_8erkck', # juggling machine 2
]

html = display_videos(videos)
HTML(html)
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/kSJqxs2Jh-I"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
#                     allowfullscreen
#                     style="border: 1px solid #ccc;">
#             </iframe>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://www.youtube.com/watch?v=kSJqxs2Jh-I">Watch on YouTube</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/M4f4xVJPrs4"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
# ...

# %% [markdown]
# ### Inclined Tables as Human Juggling Surfaces

# %%
# https://juggle.fandom.com/wiki/Roll_juggling
youtube_urls = [
    'https://www.youtube.com/watch?v=JCDv0zW8Jyc', # billiard juggling
    'https://www.youtube.com/watch?v=pdgG3zV_2Ak',  
    'https://www.youtube.com/watch?v=1u55f8nBBCk',
    'https://www.youtube.com/watch?v=Md321Uf3DZE',
    'https://www.youtube.com/watch?v=ve2EkN915oo'
]
html = display_videos(youtube_urls)
HTML(html)
# Out:
# <div style="display: flex; gap: 10px; flex-wrap: wrap;">
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/JCDv0zW8Jyc"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
#                     allowfullscreen
#                     style="border: 1px solid #ccc;">
#             </iframe>
#             <figcaption style="text-align: center; margin-top: 10px; width:300px">
#                 <a href="https://www.youtube.com/watch?v=JCDv0zW8Jyc">Watch on YouTube</a>
#             </figcaption>
#         </figure>
#
#         <figure style="text-align: center; margin: 0;">
#             <iframe width="300"
#                     height="225"
#                     src="https://www.youtube.com/embed/pdgG3zV_2Ak"
#                     frameborder="0"
#                     allow="autoplay; encrypted-media"
# ...

# %% [markdown]
# #### Kouta Ohashi - marble and rubber bands

# %%
youtube_urls = [
    'https://www.youtube.com/embed/io5EKvwD3UE',
'https://www.youtube.com/shorts/RzzuFDtEhzE',
'https://www.youtube.com/shorts/o2IHIkvjR1c',
'https://www.youtube.com/shorts/cNEUMcU0dbY',
'https://www.youtube.com/shorts/jC2lLWNnS_g',
'https://www.youtube.com/shorts/xVDEnkdcnw4',
'https://www.youtube.com/shorts/MCid_p3ZDts',
'https://www.youtube.com/shorts/675CJ4yWUjA',
'https://www.youtube.com/shorts/7H7rwNcMmTM',
'https://www.youtube.com/shorts/_nSmjScotrg',
'https://www.youtube.com/shorts/rhMWonLvxEk',
'https://www.youtube.com/shorts/iTLXhKKA-ds',
'https://www.youtube.com/shorts/x1ANSzD9UEY',
'https://www.youtube.com/shorts/8EyfxRQ-R-c',
'https://www.youtube.com/shorts/bc--LDu88pI',
'https://www.youtube.com/shorts/1mwveIUalBk',
'https://www.youtube.com/shorts/ww5vhxUoHVM',
]
    
columns = 3
width=200
height=350
html = f'<div style="display: grid; grid-template-columns: repeat({columns}, 1fr); gap: 20px;">'
    
for url in youtube_urls:
    video_id = url.split('/')[-1]
    html += f'''
    <div style="display: flex; justify-content: center;">
        <iframe 
            width="{width}" 
            height="{height}" 
            src="https://www.youtube.com/embed/{video_id}" 
            title="YouTube Short" 
            frameborder="0" 
            allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" 
            allowfullscreen>
        </iframe>
    </div>
    '''

html += '</div>'
display(HTML(html))
# Out:
# <div style="display: grid; grid-template-columns: repeat(3, 1fr); gap: 20px;">
#     <div style="display: flex; justify-content: center;">
#         <iframe
#             width="200"
#             height="350"
#             src="https://www.youtube.com/embed/io5EKvwD3UE"
#             title="YouTube Short"
#             frameborder="0"
#             allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share"
#             allowfullscreen>
#         </iframe>
#     </div>
#
#     <div style="display: flex; justify-content: center;">
#         <iframe
#             width="200"
#             height="350"
#             src="https://www.youtube.com/embed/RzzuFDtEhzE"
#             title="YouTube Short"
#             frameborder="0"
#             allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share"
#             allowfullscreen>
#         </iframe>
#     </div>
#
# ...

# %% [markdown]
# ---
# ### Techno-juggling

# %%
html = '<iframe src="https://player.vimeo.com/video/1171602382" width="640" height="360" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen></iframe>'
HTML(html)
# Out:
# C:\Users\nicor\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:447: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src="https://player.vimeo.com/video/1171602382" width="640" height="360" frameborder="0" allow="autoplay; fullscreen; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ---
# ### Iteration 3 - TV as Incline Surface
# ---

# %% [markdown]
# #### Mini Experiment 1: Projection onto Inclined Juggling Surface

# %%
html = '<iframe width="320" height="576" src="https://www.youtube.com/embed/sqHBrC4mF7g" title="Technojuggling w/ projected graphics on the table.  4 ball box" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'
HTML(html)
# Out:
# <iframe width="320" height="576" src="https://www.youtube.com/embed/sqHBrC4mF7g" title="Technojuggling w/ projected graphics on the table.  4 ball box" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# #### Mini-experiment 2: TV as Juggling Table with linearly polarized lens filter (sunglasses) for camera

# %%
html = '<iframe width="320" height="576" src="https://www.youtube.com/embed/ocGfyrQwYwI" title="Polarization effect to supress tv display" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'
HTML(html)
# Out:
# <iframe width="320" height="576" src="https://www.youtube.com/embed/ocGfyrQwYwI" title="Polarization effect to supress tv display" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
