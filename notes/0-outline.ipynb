# %% [markdown]
# ### Touchscreen Archaeology - DIY Cinema, tactile cinematic toys

# %% [markdown]
# ### Juggling in Early CGI to DJuggling

# %% [markdown]
# ### Community + Platform Study | Juggling Lab

# %% [markdown]
# ### YT-DLP and  Video Player Aesthetics
